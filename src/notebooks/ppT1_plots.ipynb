# %%
# for pp T=1, corresponding to fig. 4 on pg. 10 in "Minimally nonlocal..."
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

model_a = np.loadtxt('../model_a_pp_phases.dat', unpack=True, skiprows=1)
model_b = np.loadtxt('../model_b_pp_phases.dat', unpack=True, skiprows=1)
model_c = np.loadtxt('../model_c_pp_phases.dat', unpack=True, skiprows=1)

model_a_tilde = np.loadtxt('../model_a_tilde_pp_phases.dat', unpack=True, skiprows=1)
model_b_tilde = np.loadtxt('../model_b_tilde_pp_phases.dat', unpack=True, skiprows=1)
model_c_tilde = np.loadtxt('../model_c_tilde_pp_phases.dat', unpack=True, skiprows=1)

lab_energy=model_a[0]
lab_energy_tilde=model_a_tilde[0]
MeV = [1.00000000,5.00000000,10.00000000,25.00000000,50.00000000,100.00000000,
        150.00000000,200.00000000,250.00000000,300.00000000,350.00000000]

# %%
# 1S0 : models fitted to 125 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a=model_a[1]
sig_a=model_a[2]
b=model_b[1]
sig_b=model_b[2]
c=model_c[1]
sig_c=model_c[2]

# plots of models
ax.fill_between(lab_energy,a-sig_a,a+sig_a, color='#ee9b00', alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
ax.fill_between(lab_energy,b-sig_b,b+sig_b, color='#ae2012', alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
ax.fill_between(lab_energy,c-sig_c,c+sig_c, color='#005f73', alpha=0.75, label=r'Model c $\pm \sigma_{c}$')

# array of phases from phases_database.dat
phases_1S0 = [32.65399485,54.76014770,55.12538118,48.63876651,38.95477408,
        24.98332120,14.79671395,6.65655898,-0.17776897,-6.07831886,-11.26373899]
plt.scatter(MeV,phases_1S0, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,0.0), 300.0, 60.0, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='upper right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 4.1: $^{1}S_{0}$ fitted to 125 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(-15,60)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(-10,60,10))

plt.show()


# 1S0 : models fitted to 200 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a_tilde=model_a_tilde[1]
sig_a_tilde=model_a_tilde[2]
b_tilde=model_b_tilde[1]
sig_b_tilde=model_b_tilde[2]
c_tilde=model_c_tilde[1]
sig_c_tilde=model_c_tilde[2]

# plots of models
ax.fill_between(lab_energy_tilde,a_tilde-sig_a_tilde,a_tilde+sig_a_tilde, color='#ee9b00', alpha=0.75, label=r'Model $\tilde{a} \pm \sigma_{\tilde{a}}$')
ax.fill_between(lab_energy,b_tilde-sig_b_tilde,b_tilde+sig_b_tilde, color='#ae2012', alpha=0.75, label=r'Model $\tilde{b} \pm \sigma_{\tilde{c}}$')
ax.fill_between(lab_energy,c_tilde-sig_c_tilde,c_tilde+sig_c_tilde, color='#005f73', alpha=0.75, label=r'Model $\tilde{c} \pm \sigma_{\tilde{b}}$')

# array of phases from phases_database.dat
phases_1S0 = [32.65399485,54.76014770,55.12538118,48.63876651,38.95477408,
        24.98332120,14.79671395,6.65655898,-0.17776897,-6.07831886,-11.26373899]
plt.scatter(MeV,phases_1S0, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,0.0), 300.0, 60.0, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='upper right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 4.2: $^{1}S_{0}$ fitted to 200 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(-15,60)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(-10,60,10))

plt.show()

# %%
# 3P1 : models fitted to 125 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a=model_a[7]
sig_a=model_a[8]
b=model_b[7]
sig_b=model_b[8]
c=model_c[7]
sig_c=model_c[8]

# plots of models
ax.fill_between(lab_energy,a-sig_a,a+sig_a, color='#ee9b00', alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
ax.fill_between(lab_energy,b-sig_b,b+sig_b, color='#ae2012', alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
ax.fill_between(lab_energy,c-sig_c,c+sig_c, color='#005f73', alpha=0.75, label=r'Model c $\pm \sigma_{c}$')

# array of phases from phases_database.dat
phases_3P1 = [-0.10713374,-0.92126694,-2.03069139,-4.80541426,-8.17251143,-13.23109890,-17.53653207,
            -21.46183168,-25.08610466,-28.43998069,-31.54449062]
plt.scatter(MeV,phases_3P1, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,-30.0), 300.0, 30.0, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='upper right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 4.3: $^{3}P_{1}$ fitted to 125 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(-37,0)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(-30,0,10))

plt.show()


# 3P1 : models fitted to 200 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a_tilde=model_a_tilde[7]
sig_a_tilde=model_a_tilde[8]
b_tilde=model_b_tilde[7]
sig_b_tilde=model_b_tilde[8]
c_tilde=model_c_tilde[7]
sig_c_tilde=model_c_tilde[8]

# plots of models
ax.fill_between(lab_energy_tilde,a_tilde-sig_a_tilde,a_tilde+sig_a_tilde, color='#ee9b00', alpha=0.75, label=r'Model $\tilde{a} \pm \sigma_{\tilde{a}}$')
ax.fill_between(lab_energy,b_tilde-sig_b_tilde,b_tilde+sig_b_tilde, color='#ae2012', alpha=0.75, label=r'Model $\tilde{b} \pm \sigma_{\tilde{c}}$')
ax.fill_between(lab_energy,c_tilde-sig_c_tilde,c_tilde+sig_c_tilde, color='#005f73', alpha=0.75, label=r'Model $\tilde{c} \pm \sigma_{\tilde{b}}$')

# array of phases from phases_database.dat
phases_3P1 = [-0.10713374,-0.92126694,-2.03069139,-4.80541426,-8.17251143,-13.23109890,-17.53653207,
            -21.46183168,-25.08610466,-28.43998069,-31.54449062]
plt.scatter(MeV,phases_3P1, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,-30.0), 300.0, 30.0, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='upper right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 4.4: $^{3}P_{1}$ fitted to 200 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(-37,0)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(-30,0,10))

plt.show()

# %%
# 1D2 : models fitted to 125 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a=model_a[3]
sig_a=model_a[4]
b=model_b[3]
sig_b=model_b[4]
c=model_c[3]
sig_c=model_c[4]

# plots of models
ax.fill_between(lab_energy,a-sig_a,a+sig_a, color='#ee9b00', alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
ax.fill_between(lab_energy,b-sig_b,b+sig_b, color='#ae2012', alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
ax.fill_between(lab_energy,c-sig_c,c+sig_c, color='#005f73', alpha=0.75, label=r'Model c $\pm \sigma_{c}$')

# array of phases from phases_database.dat
phases_1D2 = [0.00077429,0.04268684,0.16648250,0.69830700,1.70749309,3.76619775,5.63198617,
             7.18815928,8.44841295,9.47113256,10.32159769]
plt.scatter(MeV,phases_1D2, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,0.0), 300, 9.3, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='upper right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 4.5: $^{1}D_{2}$ fitted to 125 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(0,11)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(0,11,2))

plt.show()


# 1D2 : models fitted to 200 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a_tilde=model_a_tilde[3]
sig_a_tilde=model_a_tilde[4]
b_tilde=model_b_tilde[3]
sig_b_tilde=model_b_tilde[4]
c_tilde=model_c_tilde[3]
sig_c_tilde=model_c_tilde[4]

# plots of models
ax.fill_between(lab_energy_tilde,a_tilde-sig_a_tilde,a_tilde+sig_a_tilde, color='#ee9b00', alpha=0.75, label=r'Model $\tilde{a} \pm \sigma_{\tilde{a}}$')
ax.fill_between(lab_energy,b_tilde-sig_b_tilde,b_tilde+sig_b_tilde, color='#ae2012', alpha=0.75, label=r'Model $\tilde{b} \pm \sigma_{\tilde{c}}$')
ax.fill_between(lab_energy,c_tilde-sig_c_tilde,c_tilde+sig_c_tilde, color='#005f73', alpha=0.75, label=r'Model $\tilde{c} \pm \sigma_{\tilde{b}}$')

# array of phases from phases_database.dat
phases_1D2 = [0.00077429,0.04268684,0.16648250,0.69830700,1.70749309,3.76619775,5.63198617,
             7.18815928,8.44841295,9.47113256,10.32159769]
plt.scatter(MeV,phases_1D2, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,0.0), 300, 9.3, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='upper right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 4.6: $^{1}D_{2}$ fitted to 200 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(0,11)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(0,11,2))

plt.show()

# %%
# 3P2 : models fitted to 125 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a=model_a[9]
sig_a=model_a[10]
b=model_b[9]
sig_b=model_b[10]
c=model_c[9]
sig_c=model_c[10]

# plots of models
ax.fill_between(lab_energy,a-sig_a,a+sig_a, color='#ee9b00', alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
ax.fill_between(lab_energy,b-sig_b,b+sig_b, color='#ae2012', alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
ax.fill_between(lab_energy,c-sig_c,c+sig_c, color='#005f73', alpha=0.75, label=r'Model c $\pm \sigma_{c}$')

# array of phases from phases_database.dat
phases_3P2 = [0.01319172,0.21675211,0.65519020,2.49460618,5.83410989,10.97547191,13.99275959,
              15.69152249,16.64312597,17.15745768,17.40530835]
plt.scatter(MeV,phases_3P2, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,0.0), 300, 22, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='lower right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 4.7: $^{3}P_{2}$ fitted to 125 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(0,22)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(0,22,5))

plt.show()


# 3P2 : models fitted to 200 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a_tilde=model_a_tilde[9]
sig_a_tilde=model_a_tilde[10]
b_tilde=model_b_tilde[9]
sig_b_tilde=model_b_tilde[10]
c_tilde=model_c_tilde[9]
sig_c_tilde=model_c_tilde[10]

# plots of models
ax.fill_between(lab_energy_tilde,a_tilde-sig_a_tilde,a_tilde+sig_a_tilde, color='#ee9b00', alpha=0.75, label=r'Model $\tilde{a} \pm \sigma_{\tilde{a}}$')
ax.fill_between(lab_energy,b_tilde-sig_b_tilde,b_tilde+sig_b_tilde, color='#ae2012', alpha=0.75, label=r'Model $\tilde{b} \pm \sigma_{\tilde{c}}$')
ax.fill_between(lab_energy,c_tilde-sig_c_tilde,c_tilde+sig_c_tilde, color='#005f73', alpha=0.75, label=r'Model $\tilde{c} \pm \sigma_{\tilde{b}}$')

# array of phases from phases_database.dat
phases_3P2 = [0.01319172,0.21675211,0.65519020,2.49460618,5.83410989,10.97547191,13.99275959,
              15.69152249,16.64312597,17.15745768,17.40530835]
plt.scatter(MeV,phases_3P2, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,0.0), 300, 22, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='lower right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 4.8: $^{3}P_{2}$ fitted to 200 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(0,22)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(0,22,5))

plt.show()

# %%
# 3P0 : models fitted to 125 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a=model_a[5]
sig_a=model_a[6]
b=model_b[5]
sig_b=model_b[6]
c=model_c[5]
sig_c=model_c[6]

# plots of models
ax.fill_between(lab_energy,a-sig_a,a+sig_a, color='#ee9b00', alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
ax.fill_between(lab_energy,b-sig_b,b+sig_b, color='#ae2012', alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
ax.fill_between(lab_energy,c-sig_c,c+sig_c, color='#005f73', alpha=0.75, label=r'Model c $\pm \sigma_{c}$')

# array of phases from phases_database.dat
phases_3P0 = [0.13318979,1.58070057,3.73020505,8.60476777,11.57798585,9.57762308,
               4.76558400,-0.46180010,-5.55424454,-10.38389855,-14.94051782]
plt.scatter(MeV,phases_3P0, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0,-20), 300, 40, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='lower left', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 4.9: $^{3}P_{0}$ fitted to 125 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
# plt.ylim(-20,20)

plt.xticks(np.arange(0,350,50))
# plt.yticks(np.arange(-20,20,10))

plt.show()


# 3P0 : models fitted to 200 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a_tilde=model_a_tilde[5]
sig_a_tilde=model_a_tilde[6]
b_tilde=model_b_tilde[5]
sig_b_tilde=model_b_tilde[6]
c_tilde=model_c_tilde[5]
sig_c_tilde=model_c_tilde[6]

# plots of models
ax.fill_between(lab_energy_tilde,a_tilde-sig_a_tilde,a_tilde+sig_a_tilde, color='#ee9b00', alpha=0.75, label=r'Model $\tilde{a} \pm \sigma_{\tilde{a}}$')
ax.fill_between(lab_energy,b_tilde-sig_b_tilde,b_tilde+sig_b_tilde, color='#ae2012', alpha=0.75, label=r'Model $\tilde{b} \pm \sigma_{\tilde{c}}$')
ax.fill_between(lab_energy,c_tilde-sig_c_tilde,c_tilde+sig_c_tilde, color='#005f73', alpha=0.75, label=r'Model $\tilde{c} \pm \sigma_{\tilde{b}}$')

# array of phases from phases_database.dat
phases_3P0 = [0.13318979,1.58070057,3.73020505,8.60476777,11.57798585,9.57762308,
               4.76558400,-0.46180010,-5.55424454,-10.38389855,-14.94051782]
plt.scatter(MeV,phases_3P0, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0,-20), 300, 40, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='lower left', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 4.10: $^{3}P_{0}$ fitted to 200 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
# plt.ylim(-20,20)

plt.xticks(np.arange(0,350,50))
# plt.yticks(np.arange(-20,20,10))

plt.show()

# %%
# e2 : models fitted to 125 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a=model_a[11]
sig_a=model_a[12]
b=model_b[11]
sig_b=model_b[12]
c=model_c[11]


# plots of models
ax.fill_between(lab_energy,a-sig_a,a+sig_a, color='#ee9b00', alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
ax.fill_between(lab_energy,b-sig_b,b+sig_b, color='#ae2012', alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
ax.fill_between(lab_energy,c-sig_c,c+sig_c, color='#005f73', alpha=0.75, label=r'Model c $\pm \sigma_{c}$')

# array of phases from phases_database.dat
phases_epsilon2 = [-0.00092597,-0.05184648,-0.20046196,-0.81226723,-1.71602844,-2.67413669,
                    -2.91173133,-2.81332115,-2.58058073,-2.31011677,-2.04972923]
plt.scatter(MeV,phases_epsilon2, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0,-4), 300, 4, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='lower right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 4.11: $\epsilon_{2}$ fitted to 125 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(-4,0)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(-4,0,1))

plt.show()


# e2 : models fitted to 200 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a_tilde=model_a_tilde[11]
sig_a_tilde=model_a_tilde[12]
b_tilde=model_b_tilde[11]
sig_b_tilde=model_b_tilde[12]
c_tilde=model_c_tilde[11]
sig_c_tilde=model_c_tilde[12]

# plots of models
ax.fill_between(lab_energy_tilde,a_tilde-sig_a_tilde,a_tilde+sig_a_tilde, color='#ee9b00', alpha=0.75, label=r'Model $\tilde{a} \pm \sigma_{\tilde{a}}$')
ax.fill_between(lab_energy,b_tilde-sig_b_tilde,b_tilde+sig_b_tilde, color='#ae2012', alpha=0.75, label=r'Model $\tilde{b} \pm \sigma_{\tilde{c}}$')
ax.fill_between(lab_energy,c_tilde-sig_c_tilde,c_tilde+sig_c_tilde, color='#005f73', alpha=0.75, label=r'Model $\tilde{c} \pm \sigma_{\tilde{b}}$')

# array of phases from phases_database.dat
phases_epsilon2 = [-0.00092597,-0.05184648,-0.20046196,-0.81226723,-1.71602844,-2.67413669,
                    -2.91173133,-2.81332115,-2.58058073,-2.31011677,-2.04972923]
plt.scatter(MeV,phases_epsilon2, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0,-4), 300, 4, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='lower right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 4.12: $\epsilon_{2}$ fitted to 200 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(-4,0)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(-4,0,1))

plt.show()
