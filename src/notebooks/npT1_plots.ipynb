# %%
# for np T=1, corresponding to fig. 3 on pg. 9 in "Minimally nonlocal..."
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

model_a = np.loadtxt('../model_a_np_phases.dat', unpack=True, skiprows=1)
model_b = np.loadtxt('../model_b_np_phases.dat', unpack=True, skiprows=1)
model_c = np.loadtxt('../model_c_np_phases.dat', unpack=True, skiprows=1)

model_a_tilde = np.loadtxt('../model_a_tilde_np_phases.dat', unpack=True, skiprows=1)
model_b_tilde = np.loadtxt('../model_b_tilde_np_phases.dat', unpack=True, skiprows=1)
model_c_tilde = np.loadtxt('../model_c_tilde_np_phases.dat', unpack=True, skiprows=1)

lab_energy=model_a[0]
lab_energy_tilde=model_a_tilde[0]
MeV = [1.00000000,5.00000000,10.00000000,25.00000000,50.00000000,100.00000000,
        150.00000000,200.00000000,250.00000000,300.00000000,350.00000000]

# %%
# 1S0 : models fitted to 125 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a=model_a[1]
sig_a=model_a[2]
b=model_b[1]
sig_b=model_b[2]
c=model_c[1]
sig_c=model_c[2]

# plots of models
ax.fill_between(lab_energy,a-sig_a,a+sig_a, color='#ee9b00', alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
ax.fill_between(lab_energy,b-sig_b,b+sig_b, color='#ae2012', alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
ax.fill_between(lab_energy,c-sig_c,c+sig_c, color='#005f73', alpha=0.75, label=r'Model c $\pm \sigma_{c}$')

# array of phases from phases_database.dat
phases_1S0 = [62.05220239,63.57614778,59.86732274,50.75646349,40.29634997,
            26.22893930,16.12033701,8.02475062,1.17421026,-4.82096557,-10.20163630]
plt.scatter(MeV,phases_1S0, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,0.0), 300.0, 60.0, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='upper right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 3.1: $^{1}S_{0}$ fitted to 125 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(-15,65)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(-10,65,20))

plt.show()

# 1S0 : models fitted to 200 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a_tilde=model_a_tilde[1]
sig_a_tilde=model_a_tilde[2]
b_tilde=model_b_tilde[1]
sig_b_tilde=model_b_tilde[2]
c_tilde=model_c_tilde[1]
sig_c_tilde=model_c_tilde[2]

# plots of models
ax.fill_between(lab_energy_tilde,a_tilde-sig_a_tilde,a_tilde+sig_a_tilde, color='#ee9b00', alpha=0.75, label=r'Model $\tilde{a} \pm \sigma_{\tilde{a}}$')
ax.fill_between(lab_energy,b_tilde-sig_b_tilde,b_tilde+sig_b_tilde, color='#ae2012', alpha=0.75, label=r'Model $\tilde{b} \pm \sigma_{\tilde{b}}$')
ax.fill_between(lab_energy,c_tilde-sig_c_tilde,c_tilde+sig_c_tilde, color='#005f73', alpha=0.75, label=r'Model $\tilde{c} \pm \sigma_{\tilde{c}}$')

# array of phases from phases_database.dat
phases_1S0 = [62.05220239,63.57614778,59.86732274,50.75646349,40.29634997,
            26.22893930,16.12033701,8.02475062,1.17421026,-4.82096557,-10.20163630]
plt.scatter(MeV,phases_1S0, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,0.0), 300.0, 60.0, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='upper right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 3.2: $^{1}S_{0}$ fitted to 200 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(-15,65)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(-10,65,20))

plt.show()

# %%
# 3P1 : models fitted to 125 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a=model_a[7]
sig_a=model_a[8]
b=model_b[7]
sig_b=model_b[8]
c=model_c[7]
sig_c=model_c[8]

# plots of models
ax.fill_between(lab_energy,a-sig_a,a+sig_a, color='#ee9b00', alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
ax.fill_between(lab_energy,b-sig_b,b+sig_b, color='#ae2012', alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
ax.fill_between(lab_energy,c-sig_c,c+sig_c, color='#005f73', alpha=0.75, label=r'Model c $\pm \sigma_{c}$')

# array of phases from phases_database.dat
phases_3P1 = [-0.10713374,-0.92126694,-2.03069139,-4.80541426,-8.17251143,-13.23109890,-17.53653207,
            -21.46183168,-25.08610466,-28.43998069,-31.54449062]
plt.scatter(MeV,phases_3P1, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,-30.0), 300.0, 30.0, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='upper right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 3.3: $^{3}P_{1}$ fitted to 125 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(-40,0)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(-40,0,10))

plt.show()


# 3P1 : models fitted to 200 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a_tilde=model_a_tilde[7]
sig_a_tilde=model_a_tilde[8]
b_tilde=model_b_tilde[7]
sig_b_tilde=model_b_tilde[8]
c_tilde=model_c_tilde[7]
sig_c_tilde=model_c_tilde[8]

# plots of models
ax.fill_between(lab_energy_tilde,a_tilde-sig_a_tilde,a_tilde+sig_a_tilde, color='#ee9b00', alpha=0.75, label=r'Model $\tilde{a} \pm \sigma_{\tilde{a}}$')
ax.fill_between(lab_energy,b_tilde-sig_b_tilde,b_tilde+sig_b_tilde, color='#ae2012', alpha=0.75, label=r'Model $\tilde{b} \pm \sigma_{\tilde{b}}$')
ax.fill_between(lab_energy,c_tilde-sig_c_tilde,c_tilde+sig_c_tilde, color='#005f73', alpha=0.75, label=r'Model $\tilde{c} \pm \sigma_{\tilde{c}}$')

# array of phases from phases_database.dat
phases_3P1 = [-0.10713374,-0.92126694,-2.03069139,-4.80541426,-8.17251143,-13.23109890,-17.53653207,
            -21.46183168,-25.08610466,-28.43998069,-31.54449062]
plt.scatter(MeV,phases_3P1, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,-30.0), 300.0, 30.0, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='upper right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 3.4: $^{3}P_{1}$ fitted to 200 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(-40,0)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(-40,0,10))

plt.show()

# %%
# 1D2 : models fitted to 125 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a=model_a[15]
sig_a=model_a[16]
b=model_b[15]
sig_b=model_b[16]
c=model_c[15]
sig_c=model_c[16]

# plots of models
ax.fill_between(lab_energy,a-sig_a,a+sig_a, color='#ee9b00', alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
ax.fill_between(lab_energy,b-sig_b,b+sig_b, color='#ae2012', alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
ax.fill_between(lab_energy,c-sig_c,c+sig_c, color='#005f73', alpha=0.75, label=r'Model c $\pm \sigma_{c}$')

# array of phases from phases_database.dat
phases_1D2 = [0.00080029,0.04114518,0.15651692,0.67618889,1.70282421,3.82331327,
            5.73545602,7.30872944,8.55402292,9.52821461,10.29881099]
plt.scatter(MeV,phases_1D2, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,0.0), 300, 9.3, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='lower right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 3.5: $^{1}D_{2}$ fitted to 125 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(0,11)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(0,11,2))

plt.show()


# 1D2 : models fitted to 200 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a_tilde=model_a_tilde[15]
sig_a_tilde=model_a_tilde[16]
b_tilde=model_b_tilde[15]
sig_b_tilde=model_b_tilde[16]
c_tilde=model_c_tilde[15]
sig_c_tilde=model_c_tilde[16]

# plots of models
ax.fill_between(lab_energy_tilde,a_tilde-sig_a_tilde,a_tilde+sig_a_tilde, color='#ee9b00', alpha=0.75, label=r'Model $\tilde{a} \pm \sigma_{\tilde{a}}$')
ax.fill_between(lab_energy,b_tilde-sig_b_tilde,b_tilde+sig_b_tilde, color='#ae2012', alpha=0.75, label=r'Model $\tilde{b} \pm \sigma_{\tilde{b}}$')
ax.fill_between(lab_energy,c_tilde-sig_c_tilde,c_tilde+sig_c_tilde, color='#005f73', alpha=0.75, label=r'Model $\tilde{c} \pm \sigma_{\tilde{c}}$')

# array of phases from phases_database.dat
phases_1D2 = [0.00080029,0.04114518,0.15651692,0.67618889,1.70282421,3.82331327,
            5.73545602,7.30872944,8.55402292,9.52821461,10.29881099]
plt.scatter(MeV,phases_1D2, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,0.0), 300, 9.3, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='lower right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 3.6: $^{1}D_{2}$ fitted to 200 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(0,11)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(0,11,2))

plt.show()

# %%
# 3P2 : models fitted to 200 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a=model_a[19]
sig_a=model_a[20]
b=model_b[19]
sig_b=model_b[20]
c=model_c[19]
sig_c=model_c[20]


# plots of models
ax.fill_between(lab_energy,a-sig_a,a+sig_a, color='#ee9b00', alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
ax.fill_between(lab_energy,b-sig_b,b+sig_b, color='#ae2012', alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
ax.fill_between(lab_energy,c-sig_c,c+sig_c, color='#005f73', alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
# array of phases from phases_database.dat
phases_3P2 = [0.02105386,0.25464598,0.71775347,2.58906097,5.91507412,10.95759415,13.87412958,
            15.48840666,16.36274252,16.79791199,16.96057580]
plt.scatter(MeV,phases_3P2, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,0.0), 300, 22, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='lower right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 3.7: $^{3}P_{2}$ fitted to 125 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(0,22)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(0,22,5))

plt.show()


# 3P2 : models fitted to 200 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a_tilde=model_a_tilde[19]
sig_a_tilde=model_a_tilde[20]
b_tilde=model_b_tilde[19]
sig_b_tilde=model_b_tilde[20]
c_tilde=model_c_tilde[19]
sig_c_tilde=model_c_tilde[20]

# plots of models
ax.fill_between(lab_energy_tilde,a_tilde-sig_a_tilde,a_tilde+sig_a_tilde, color='#ee9b00', alpha=0.75, label=r'Model $\tilde{a} \pm \sigma_{\tilde{a}}$')
ax.fill_between(lab_energy,b_tilde-sig_b_tilde,b_tilde+sig_b_tilde, color='#ae2012', alpha=0.75, label=r'Model $\tilde{b} \pm \sigma_{\tilde{c}}$')
ax.fill_between(lab_energy,c_tilde-sig_c_tilde,c_tilde+sig_c_tilde, color='#005f73', alpha=0.75, label=r'Model $\tilde{c} \pm \sigma_{\tilde{b}}$')

# array of phases from phases_database.dat
phases_3P2 = [0.02105386,0.25464598,0.71775347,2.58906097,5.91507412,10.95759415,13.87412958,
            15.48840666,16.36274252,16.79791199,16.96057580]
plt.scatter(MeV,phases_3P2, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,0.0), 300, 22, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='lower right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 3.8: $^{3}P_{2}$ fitted to 200 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(0,22)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(0,22,5))

plt.show()

# %%
# 3P0 : models fitted to 125 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a=model_a[3]
sig_a=model_a[4]
b=model_b[3]
sig_b=model_b[4]
c=model_c[3]
sig_c=model_c[4]

# plots of models
ax.fill_between(lab_energy,a-sig_a,a+sig_a, color='#ee9b00', alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
ax.fill_between(lab_energy,b-sig_b,b+sig_b, color='#ae2012', alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
ax.fill_between(lab_energy,c-sig_c,c+sig_c, color='#005f73', alpha=0.75, label=r'Model c $\pm \sigma_{c}$')

# array of phases from phases_database.dat
phases_3P0 = [0.18602397,1.62770064,3.65243785,8.16903435,10.83549428,8.66082290,3.83202605,-1.36373801,
            -6.39594541,-11.14067945,-15.59043269]
plt.scatter(MeV,phases_3P0, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0,-20), 300, 40, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='upper right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 3.9: $^{3}P_{0}$ fitted to 125 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(-20,20)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(-20,20,10))

plt.show()


# 3P0 : models fitted to 200 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a_tilde=model_a_tilde[3]
sig_a_tilde=model_a_tilde[4]
b_tilde=model_b_tilde[3]
sig_b_tilde=model_b_tilde[4]
c_tilde=model_c_tilde[3]
sig_c_tilde=model_c_tilde[4]

# plots of models
ax.fill_between(lab_energy_tilde,a_tilde-sig_a_tilde,a_tilde+sig_a_tilde, color='#ee9b00', alpha=0.75, label=r'Model $\tilde{a} \pm \sigma_{\tilde{a}}$')
ax.fill_between(lab_energy,b_tilde-sig_b_tilde,b_tilde+sig_b_tilde, color='#ae2012', alpha=0.75, label=r'Model $\tilde{b} \pm \sigma_{\tilde{b}}$')
ax.fill_between(lab_energy,c_tilde-sig_c_tilde,c_tilde+sig_c_tilde, color='#005f73', alpha=0.75, label=r'Model $\tilde{c} \pm \sigma_{\tilde{c}}$')

# array of phases from phases_database.dat
phases_3P0 = [0.18602397,1.62770064,3.65243785,8.16903435,10.83549428,8.66082290,3.83202605,-1.36373801,
            -6.39594541,-11.14067945,-15.59043269]
plt.scatter(MeV,phases_3P0, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0,-20), 300, 40, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='upper right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 3.10: $^{3}P_{0}$ fitted to 200 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(-20,20)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(-20,20,10))

plt.show()

# %%
# e2 : models fitted to 125 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

fig, ax = plt.subplots(1, figsize=(8,8))

a=model_a[21]
sig_a=model_a[22]
b=model_b[21]
sig_b=model_b[22]
c=model_c[21]
sig_c=model_c[22]

# plots of models
ax.fill_between(lab_energy,a-sig_a,a+sig_a, color='#ee9b00', alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
ax.fill_between(lab_energy,b-sig_b,b+sig_b, color='#ae2012', alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
ax.fill_between(lab_energy,c-sig_c,c+sig_c, color='#005f73', alpha=0.75, label=r'Model c $\pm \sigma_{c}$')

# array of phases from phases_database.dat
phases_epsilon2 = [-0.00109629,-0.04946051,-0.18293715,-0.74960574,-1.61862709,-2.56831053,-2.81685855,
            -2.73312463,-2.50949689,-2.24698695,-1.98933133]
plt.scatter(MeV,phases_epsilon2, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0,-4), 300, 4, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='upper center', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 3.11: $\epsilon_{2}$ fitted to 125 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(-4,0)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(-4,0,1))

plt.show()

# e2 : models fitted to 200 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a_tilde=model_a_tilde[21]
sig_a_tilde=model_a_tilde[22]
b_tilde=model_b_tilde[21]
sig_b_tilde=model_b_tilde[22]
c_tilde=model_c_tilde[21]
sig_c_tilde=model_c_tilde[22]

# plots of models
ax.fill_between(lab_energy_tilde,a_tilde-sig_a_tilde,a_tilde+sig_a_tilde, color='#ee9b00', alpha=0.75, label=r'Model $\tilde{a} \pm \sigma_{\tilde{a}}$')
ax.fill_between(lab_energy,b_tilde-sig_b_tilde,b_tilde+sig_b_tilde, color='#ae2012', alpha=0.75, label=r'Model $\tilde{b} \pm \sigma_{\tilde{b}}$')
ax.fill_between(lab_energy,c_tilde-sig_c_tilde,c_tilde+sig_c_tilde, color='#005f73', alpha=0.75, label=r'Model $\tilde{c} \pm \sigma_{\tilde{c}}$')

# array of phases from phases_database.dat
phases_epsilon2 = [-0.00109629,-0.04946051,-0.18293715,-0.74960574,-1.61862709,-2.56831053,-2.81685855,
            -2.73312463,-2.50949689,-2.24698695,-1.98933133]
plt.scatter(MeV,phases_epsilon2, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0,-4), 300, 4, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='upper center', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 3.12: $\epsilon_{2}$ fitted to 200 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(-4,0)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(-4,0,1))

plt.show()
