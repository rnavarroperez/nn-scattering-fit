# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

model_a = np.loadtxt('../model_a_300_deuteron_np_v_partial_wave.dat', unpack=True, skiprows=1)
model_b = np.loadtxt('../model_b_300_deuteron_np_v_partial_wave.dat', unpack=True, skiprows=1)
model_c = np.loadtxt('../model_c_300_deuteron_np_v_partial_wave.dat', unpack=True, skiprows=1)
model_c_tilde = np.loadtxt('../model_c_tilde_np_v_partial_wave.dat', unpack=True, skiprows=1)
fm = model_c[0]

model_a_phase = np.loadtxt('../model_a_300_deuteron_np_phases.dat', unpack=True, skiprows=1)
model_b_phase = np.loadtxt('../model_b_300_deuteron_np_phases.dat', unpack=True, skiprows=1)
model_c_phase = np.loadtxt('../model_c_300_deuteron_np_phases.dat', unpack=True, skiprows=1)
model_c_tilde_phase = np.loadtxt('../model_c_tilde_np_phases.dat', unpack=True, skiprows=1)

lab_energy=model_c_phase[0]
MeV = [1.00000000,5.00000000,10.00000000,25.00000000,50.00000000,100.00000000,
        150.00000000,200.00000000,250.00000000,300.00000000,350.00000000]

# %%
# 1S0 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(6,6))

a=model_a[1]
sig_a=model_a[2]
b=model_b[1]
sig_b=model_b[2]
c=model_c[1]
sig_c=model_c[2]
c_tilde=model_c_tilde[1]

# plots of models
ax.fill_between(fm,a-sig_a,a+sig_a, color='#ee9b00', alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
ax.fill_between(fm,b-sig_b,b+sig_b, color='#ae2012', alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
ax.fill_between(fm,c-sig_c,c+sig_c, color='#005f73', alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
ax.plot(fm,c_tilde, color='black', label=r'Model $\tilde{\mathrm{c}}$')

plt.legend(loc='upper right', fontsize=15)
plt.xlabel('r [fm]', fontsize=15)
plt.ylabel('$V_{^1S_0}$ [MeV]', fontsize=15)

# Set limits
plt.xlim(0,2)
# plt.ylim(-15,65)

# plt.xticks(np.arange(0,350,50))
# plt.yticks(np.arange(-10,65,20))

plt.show()

# %%
# 3P0 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a=model_a[3]
sig_a=model_a[4]
b=model_b[3]
sig_b=model_b[4]
c=model_c[3]
sig_c=model_c[4]
c_tilde=model_c_tilde[3]

# plots of models
ax.fill_between(fm,a-sig_a,a+sig_a, color='#ee9b00', alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
ax.fill_between(fm,b-sig_b,b+sig_b, color='#ae2012', alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
ax.fill_between(fm,c-sig_c,c+sig_c, color='#005f73', alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
ax.plot(fm,c_tilde, color='black', label=r'Model $\tilde{\mathrm{c}}$')

plt.legend(loc='upper right', fontsize=15)
plt.xlabel('r [fm]', fontsize=15)
plt.ylabel('$V_{^3P_0}$ [MeV]', fontsize=15)

# Set limits
plt.xlim(0,2)
# plt.ylim(-20,20)

# plt.xticks(np.arange(0,350,50))
# plt.yticks(np.arange(-20,20,10))

plt.show()

# %%
# 1P1 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a=model_a[5]
sig_a=model_a[6]
b=model_b[5]
sig_b=model_b[6]
c=model_c[5]
sig_c=model_c[6]
c_tilde=model_c_tilde[5]

# plots of models
ax.fill_between(fm,a-sig_a,a+sig_a, color='#ee9b00', alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
ax.fill_between(fm,b-sig_b,b+sig_b, color='#ae2012', alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
ax.fill_between(fm,c-sig_c,c+sig_c, color='#005f73', alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
ax.plot(fm,c_tilde, color='black', label=r'Model $\tilde{\mathrm{c}}$')

plt.legend(loc='upper right', fontsize=15)
plt.xlabel('r [fm]', fontsize=15)
plt.ylabel('$V_{^1P_1}$ [MeV]', fontsize=15)

# Set limits
plt.xlim(0,2)
# plt.ylim(-30,0)

# plt.xticks(np.arange(0,350,50))
# plt.yticks(np.arange(-30,0,10))

plt.show()

# %%
# 3P1 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a=model_a[7]
sig_a=model_a[8]
b=model_b[7]
sig_b=model_b[8]
c=model_c[7]
sig_c=model_c[8]
c_tilde=model_c_tilde[7]

# plots of models
ax.fill_between(fm,a-sig_a,a+sig_a, color='#ee9b00', alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
ax.fill_between(fm,b-sig_b,b+sig_b, color='#ae2012', alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
ax.fill_between(fm,c-sig_c,c+sig_c, color='#005f73', alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
ax.plot(fm,c_tilde, color='black', label=r'Model $\tilde{\mathrm{c}}$')

plt.legend(loc='upper right', fontsize=15)
plt.xlabel('r [fm]', fontsize=15)
plt.ylabel('$V_{^3P_1}$ [MeV]', fontsize=15)

# Set limits
plt.xlim(0,2)
# plt.ylim(-37,0)

# plt.xticks(np.arange(0,350,50))
# plt.yticks(np.arange(-30,0,10))

plt.show()

# %%
# 3S1 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a=model_a[9]
sig_a=model_a[10]
b=model_b[9]
sig_b=model_b[10]
c=model_c[9]
sig_c=model_c[10]
c_tilde=model_c_tilde[9]

# plots of models
ax.fill_between(fm,a-sig_a,a+sig_a, color='#ee9b00', alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
ax.fill_between(fm,b-sig_b,b+sig_b, color='#ae2012', alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
ax.fill_between(fm,c-sig_c,c+sig_c, color='#005f73', alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
ax.plot(fm,c_tilde, color='black', label=r'Model $\tilde{\mathrm{c}}$')

plt.legend(loc='upper right', fontsize=15)
plt.xlabel('r [fm]', fontsize=15)
plt.ylabel('$V_{^3S_1}$ [MeV]', fontsize=15)

# Set limits
plt.xlim(0,2)
# plt.ylim(0,150)

# plt.xticks(np.arange(0,350,50))
# plt.yticks(np.arange(0,150,50))

plt.show()

# %%
# e1 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a=model_a[11]
sig_a=model_a[12]
b=model_b[11]
sig_b=model_b[12]
c=model_c[11]
sig_c=model_c[12]
c_tilde=model_c_tilde[11]

# plots of models
ax.fill_between(fm,a-sig_a,a+sig_a, color='#ee9b00', alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
ax.fill_between(fm,b-sig_b,b+sig_b, color='#ae2012', alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
ax.fill_between(fm,c-sig_c,c+sig_c, color='#005f73', alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
ax.plot(fm,c_tilde, color='black', label=r'Model $\tilde{\mathrm{c}}$')

plt.legend(loc='upper right', fontsize=15)
plt.xlabel('r [fm]', fontsize=15)
plt.ylabel('$V_{\epsilon_1}$ [MeV]', fontsize=15)

# Set limits
plt.xlim(0,2)
# plt.ylim(0,5)

# plt.xticks(np.arange(0,350,50))
# plt.yticks(np.arange(0,5,1))

plt.show()

# %%
# 3D1 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a=model_a[13]
sig_a=model_a[14]
b=model_b[13]
sig_b=model_b[14]
c=model_c[13]
sig_c=model_c[14]
c_tilde=model_c_tilde[13]

# plots of models
ax.fill_between(fm,a-sig_a,a+sig_a, color='#ee9b00', alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
ax.fill_between(fm,b-sig_b,b+sig_b, color='#ae2012', alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
ax.fill_between(fm,c-sig_c,c+sig_c, color='#005f73', alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
ax.plot(fm,c_tilde, color='black', label=r'Model $\tilde{\mathrm{c}}$')

plt.legend(loc='upper right', fontsize=15)
plt.xlabel('r [fm]', fontsize=15)
plt.ylabel('$V_{^3D_1}$ [MeV]', fontsize=15)

# Set limits
plt.xlim(0,2)
# plt.ylim(-30,0)

# plt.xticks(np.arange(0,125,50))
# plt.yticks(np.arange(-30,0,5))

plt.show()

# %%
# 1D2 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a=model_a[15]
sig_a=model_a[16]
b=model_b[15]
sig_b=model_b[16]
c=model_c[15]
sig_c=model_c[16]
c_tilde=model_c_tilde[15]

# plots of models
ax.fill_between(fm,a-sig_a,a+sig_a, color='#ee9b00', alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
ax.fill_between(fm,b-sig_b,b+sig_b, color='#ae2012', alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
ax.fill_between(fm,c-sig_c,c+sig_c, color='#005f73', alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
ax.plot(fm,c_tilde, color='black', label=r'Model $\tilde{\mathrm{c}}$')

plt.legend(loc='upper right', fontsize=15)
plt.xlabel('r [fm]', fontsize=15)
plt.ylabel('$V_{^1D_2}$ [MeV]', fontsize=15)

# Set limits
plt.xlim(0,2)
# plt.ylim(-30,0)

# plt.xticks(np.arange(0,125,50))
# plt.yticks(np.arange(-30,0,5))

plt.show()

# %%
# partial waves in 1 figure
fig = plt.figure(figsize=(12,5))
gs = fig.add_gridspec(2, 4, hspace=0)
axs = gs.subplots(sharex='col')

# set plot colors
a_color = 'C0'
b_color = 'C1'
c_color = 'C2'
c_tilde_color = 'black'
phases_color = 'C3'

# set font sizes
title_font_size = '16'
label_font_size = '12'
tick_font_size = '8'

# set zorders
ylabel_order = 10
c_tilde_order = 0

# set limits
xmin,xmax = 0,2

# set # of axis ticks
x_ticks = 2
y_ticks = 5

# other parameters
ytick_rotation = 0
yhcoord, yvcoord = 0.95,0.5
label_box = dict(facecolor='white', edgecolor='None', alpha=0.85, boxstyle='round,pad=0.2')

for axi in axs.flat:

    axi.set_xlim(xmin,xmax)                                         # set x-axis limits
    axi.xaxis.set_major_locator(plt.MaxNLocator(x_ticks))           # determines where ticks are on x-axis
    axi.yaxis.set_major_locator(plt.MaxNLocator(y_ticks))           # determines where ticks are on y-axis
    axi.tick_params(axis='x',labelsize=tick_font_size)              # sets font-size of x-ticks
    axi.tick_params(axis='y',labelsize=tick_font_size)              # sets font-size of y-ticks
    axi.set_box_aspect(1)                                           # forces all plots to be square
    axi.yaxis.set_label_coords(yhcoord, yvcoord)                    # sets location of y-label
    axi.set_xlabel('r [fm]', fontsize=label_font_size)              # labels x-axis for all plots


# 1S0 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
a1=model_a[1]
sig_a1=model_a[2]
b1=model_b[1]
sig_b1=model_b[2]
c1=model_c[1]
sig_c1=model_c[2]
c1_tilde=model_c_tilde[1]

axs[0,0].fill_between(fm,a1-sig_a1,a1+sig_a1, color=a_color, alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
axs[0,0].fill_between(fm,b1-sig_b1,b1+sig_b1, color=b_color, alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
axs[0,0].fill_between(fm,c1-sig_c1,c1+sig_c1, color=c_color, alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
axs[0,0].plot(fm,c1_tilde, color=c_tilde_color, label=r'Model $\tilde{\mathrm{c}}$', zorder=c_tilde_order)

# labels
axs[0,0].set_ylabel('$V_{^1S_0}$ [MeV]', fontsize=label_font_size, bbox=label_box).set_zorder(ylabel_order)

# axs[0,0].legend(loc='upper right', fontsize=label_font_size)

# 3P0 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
a2=model_a[3]
sig_a2=model_a[4]
b2=model_b[3]
sig_b2=model_b[4]
c2=model_c[3]
sig_c2=model_c[4]
c2_tilde=model_c_tilde[3]

axs[1,0].fill_between(fm,a2-sig_a2,a2+sig_a2, color=a_color, alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
axs[1,0].fill_between(fm,b2-sig_b2,b2+sig_b2, color=b_color, alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
axs[1,0].fill_between(fm,c2-sig_c2,c2+sig_c2, color=c_color, alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
axs[1,0].plot(fm,c2_tilde, color=c_tilde_color, label=r'Model $\tilde{\mathrm{c}}$', zorder=c_tilde_order)

# labels
axs[1,0].set_ylabel('$V_{^3P_0}$ [MeV]', fontsize=label_font_size, bbox=label_box).set_zorder(ylabel_order)

# 1P1 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
a3=model_a[5]
sig_a3=model_a[6]
b3=model_b[5]
sig_b3=model_b[6]
c3=model_c[5]
sig_c3=model_c[6]
c3_tilde=model_c_tilde[5]

axs[0,1].fill_between(fm,a3-sig_a3,a3+sig_a3, color=a_color, alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
axs[0,1].fill_between(fm,b3-sig_b3,b3+sig_b3, color=b_color, alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
axs[0,1].fill_between(fm,b3-sig_b3,b3+sig_b3, color=b_color, alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
axs[0,1].fill_between(fm,c3-sig_c3,c3+sig_c3, color=c_color, alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
axs[0,1].plot(fm,c3_tilde, color=c_tilde_color, label=r'Model $\tilde{\mathrm{c}}$', zorder=c_tilde_order)

# labels
axs[0,1].set_ylabel('$V_{^1P_1}$ [MeV]', fontsize=label_font_size, bbox=label_box).set_zorder(ylabel_order)

# 3P1 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
a4=model_a[7]
sig_a4=model_a[8]
b4=model_b[7]
sig_b4=model_b[8]
c4=model_c[7]
sig_c4=model_c[8]
c4_tilde=model_c_tilde[7]

axs[1,1].fill_between(fm,a4-sig_a4,a4+sig_a4, color=a_color, alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
axs[1,1].fill_between(fm,b4-sig_b4,b4+sig_b4, color=b_color, alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
axs[1,1].fill_between(fm,c4-sig_c4,c4+sig_c4, color=c_color, alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
axs[1,1].plot(fm,c4_tilde, color=c_tilde_color, label=r'Model $\tilde{\mathrm{c}}$', zorder=c_tilde_order)

# labels
axs[1,1].set_ylabel('$V_{^3P_1}$ [MeV]', fontsize=label_font_size, bbox=label_box).set_zorder(ylabel_order)

# 3S1 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
a5=model_a[9]
sig_a5=model_a[10]
b5=model_b[9]
sig_b5=model_b[10]
c5=model_c[9]
sig_c5=model_c[10]
c5_tilde=model_c_tilde[9]

axs[0,2].fill_between(fm,a5-sig_a5,a5+sig_a5, color=a_color, alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
axs[0,2].fill_between(fm,b5-sig_b5,b5+sig_b5, color=b_color, alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
axs[0,2].fill_between(fm,c5-sig_c5,c5+sig_c5, color=c_color, alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
axs[0,2].plot(fm,c5_tilde, color=c_tilde_color, label=r'Model $\tilde{\mathrm{c}}$', zorder=c_tilde_order)

# labels
axs[0,2].set_ylabel('$V_{^3S_1}$ [MeV]', fontsize=label_font_size, bbox=label_box).set_zorder(ylabel_order)

# e1 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
a6=model_a[11]
sig_a6=model_a[12]
b6=model_b[11]
sig_b6=model_b[12]
c6=model_c[11]
sig_c6=model_c[12]
c6_tilde=model_c_tilde[11]

axs[1,2].fill_between(fm,a6-sig_a6,a6+sig_a6, color=a_color, alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
axs[1,2].fill_between(fm,b6-sig_b6,b6+sig_b6, color=b_color, alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
axs[1,2].fill_between(fm,c6-sig_c6,c6+sig_c6, color=c_color, alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
axs[1,2].plot(fm,c6_tilde, color=c_tilde_color, label=r'Model $\tilde{\mathrm{c}}$', zorder=c_tilde_order)

# labels
axs[1,2].set_ylabel('$V_{\epsilon_1}$ [MeV]', fontsize=label_font_size, bbox=label_box).set_zorder(ylabel_order)

# 3D1 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
a7=model_a[13]
sig_a7=model_a[14]
b7=model_b[13]
sig_b7=model_b[14]
c7=model_c[13]
sig_c7=model_c[14]
c7_tilde=model_c_tilde[13]

axs[0,3].fill_between(fm,a7-sig_a7,a7+sig_a7, color=a_color, alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
axs[0,3].fill_between(fm,b7-sig_b7,b7+sig_b7, color=b_color, alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
axs[0,3].fill_between(fm,c7-sig_c7,c7+sig_c7, color=c_color, alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
axs[0,3].plot(fm,c7_tilde, color=c_tilde_color, label=r'Model $\tilde{\mathrm{c}}$', zorder=c_tilde_order)

# labels
axs[0,3].set_ylabel('$V_{^3D_1}$ [MeV]', fontsize=label_font_size, bbox=label_box).set_zorder(ylabel_order)

# 1D2 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
a8=model_a[15]
sig_a8=model_a[16]
b8=model_b[15]
sig_b8=model_b[16]
c8=model_c[15]
sig_c8=model_c[16]
c8_tilde=model_c_tilde[15]

axs[1,3].fill_between(fm,a8-sig_a8,a8+sig_a8, color=a_color, alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
axs[1,3].fill_between(fm,b8-sig_b8,b8+sig_b8, color=b_color, alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
axs[1,3].fill_between(fm,c8-sig_c8,c8+sig_c8, color=c_color, alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
axs[1,3].plot(fm,c8_tilde, color=c_tilde_color, label=r'Model $\tilde{\mathrm{c}}$', zorder=c_tilde_order)

# labels
axs[1,3].set_ylabel('$V_{^1D_2}$ [MeV]', fontsize=label_font_size, bbox=label_box).set_zorder(ylabel_order)

# legend ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
plt.legend(loc='lower center', bbox_to_anchor=(-0.45, -0.5), ncol=5)
plt.savefig('short_range_partial_waves.png', bbox_inches='tight')

# %%
fig = plt.figure(figsize=(12,36))
gs = fig.add_gridspec(8, 2, hspace=0)
axs = gs.subplots(sharex='col')

a_color = 'C0'
b_color = 'C1'
c_color = 'C2'
c_tilde_color = 'black'
phases_color = 'C3'

title_font_size = '16'
label_font_size = '14'

# 1S0 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# partial wave
a1=model_a[1]
sig_a1=model_a[2]
b1=model_b[1]
sig_b1=model_b[2]
c1=model_c[1]
sig_c1=model_c[2]
c1_tilde=model_c_tilde[1]

axs[0,0].fill_between(fm,a1-sig_a1,a1+sig_a1, color=a_color, alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
axs[0,0].fill_between(fm,b1-sig_b1,b1+sig_b1, color=b_color, alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
axs[0,0].fill_between(fm,c1-sig_c1,c1+sig_c1, color=c_color, alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
axs[0,0].plot(fm,c1_tilde, color=c_tilde_color, label=r'Model $\tilde{\mathrm{c}}$')

axs[0,0].set_ylabel('$V_{^1S_0}$ [MeV]', fontsize=label_font_size)
axs[0,0].set_title('Partial Waves', fontsize=title_font_size)
axs[0,0].set_xlim(0,2)
axs[0,0].legend(loc='upper right', fontsize=label_font_size)

# phase shift
a10=model_a_phase[1]
sig_a10=model_a_phase[2]
b10=model_b_phase[1]
sig_b10=model_b_phase[2]
c10=model_c_phase[1]
sig_c10=model_c_phase[2]
c10_tilde=model_c_tilde_phase[1]

axs[0,1].fill_between(lab_energy,a10-sig_a10,a10+sig_a10, color=a_color, alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
axs[0,1].fill_between(lab_energy,b10-sig_b10,b10+sig_b10, color=b_color, alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
axs[0,1].fill_between(lab_energy,c10-sig_c10,c10+sig_c10, color=c_color, alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
axs[0,1].plot(lab_energy,c10_tilde, color=c_tilde_color, label=r'Model $\tilde{\mathrm{c}}$')

phases_1S0 = [62.05220239,63.57614778,59.86732274,50.75646349,40.29634997,
            26.22893930,16.12033701,8.02475062,1.17421026,-4.82096557,-10.20163630]
axs[0,1].scatter(MeV,phases_1S0, color=phases_color, label=r'Phases from Database')

axs[0,1].set_ylabel('$\delta_{^1S_0}$ [deg]', fontsize=label_font_size)
axs[0,1].set_title('Phase Shifts', fontsize=title_font_size)
axs[0,1].set_xlim(0,350)
axs[0,1].legend(loc='upper right', fontsize=label_font_size)

# 3P0 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# partial wave
a2=model_a[3]
sig_a2=model_a[4]
b2=model_b[3]
sig_b2=model_b[4]
c2=model_c[3]
sig_c2=model_c[4]
c2_tilde=model_c_tilde[3]

axs[1,0].fill_between(fm,a2-sig_a2,a2+sig_a2, color=a_color, alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
axs[1,0].fill_between(fm,b2-sig_b2,b2+sig_b2, color=b_color, alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
axs[1,0].fill_between(fm,c2-sig_c2,c2+sig_c2, color=c_color, alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
axs[1,0].plot(fm,c2_tilde, color=c_tilde_color, label=r'Model $\tilde{\mathrm{c}}$')

axs[1,0].set_ylabel('$V_{^3P_0}$ [MeV]', fontsize=label_font_size)

# phase shift
a20=model_a_phase[3]
sig_a20=model_a_phase[4]
b20=model_b_phase[3]
sig_b20=model_b_phase[4]
c20=model_c_phase[3]
sig_c20=model_c_phase[4]
c20_tilde=model_c_tilde_phase[3]

axs[1,1].fill_between(lab_energy,a20-sig_a20,a20+sig_a20, color=a_color, alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
axs[1,1].fill_between(lab_energy,b20-sig_b20,b20+sig_b20, color=b_color, alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
axs[1,1].fill_between(lab_energy,c20-sig_c20,c20+sig_c20, color=c_color, alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
axs[1,1].plot(lab_energy,c20_tilde, color=c_tilde_color, label=r'Model $\tilde{\mathrm{c}}$')

phases_3P0 = [0.13318979,1.58070057,3.73020505,8.60476777,11.57798585,9.57762308,
               4.76558400,-0.46180010,-5.55424454,-10.38389855,-14.94051782]
axs[1,1].scatter(MeV,phases_3P0, color=phases_color, label=r'Phases from Database')

axs[1,1].set_ylabel('$\delta_{^3P_0}$ [deg]', fontsize=label_font_size)

# 1P1 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# partial wave
a3=model_a[5]
sig_a3=model_a[6]
b3=model_b[5]
sig_b3=model_b[6]
c3=model_c[5]
sig_c3=model_c[6]
c3_tilde=model_c_tilde[5]

axs[2,0].fill_between(fm,a3-sig_a3,a3+sig_a3, color=a_color, alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
axs[2,0].fill_between(fm,b3-sig_b3,b3+sig_b3, color=b_color, alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
axs[2,0].fill_between(fm,c3-sig_c3,c3+sig_c3, color=c_color, alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
axs[2,0].plot(fm,c3_tilde, color=c_tilde_color, label=r'Model $\tilde{\mathrm{c}}$')

axs[2,0].set_ylabel('$V_{^1P_1}$ [MeV]', fontsize=label_font_size)

# phase shift
a30=model_a_phase[5]
sig_a30=model_a_phase[6]
b30=model_b_phase[5]
sig_b30=model_b_phase[6]
c30=model_c_phase[5]
sig_c30=model_c_phase[6]
c30_tilde=model_c_tilde_phase[5]

axs[2,1].fill_between(lab_energy,a30-sig_a30,a30+sig_a30, color=a_color, alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
axs[2,1].fill_between(lab_energy,b30-sig_b30,b30+sig_b30, color=b_color, alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
axs[2,1].fill_between(lab_energy,c30-sig_c30,c30+sig_c30, color=c_color, alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
axs[2,1].plot(lab_energy,c30_tilde, color=c_tilde_color, label=r'Model $\tilde{\mathrm{c}}$')

phases_1P1 = [-0.19054091,-1.50739157,-3.08935863,-6.44480830,-9.88227497,
            -14.59991415,-18.44340152,-21.74890107,-24.58334706,-26.99613941,-29.04322442]
axs[2,1].scatter(MeV,phases_1P1, color=phases_color, label=r'Phases from Database')

axs[2,1].set_ylabel('$\delta_{^1P_1}$ [deg]', fontsize=label_font_size)

# 3P1 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# partial wave
a4=model_a[7]
sig_a4=model_a[8]
b4=model_b[7]
sig_b4=model_b[8]
c4=model_c[7]
sig_c4=model_c[8]
c4_tilde=model_c_tilde[7]

axs[3,0].fill_between(fm,a4-sig_a4,a4+sig_a4, color=a_color, alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
axs[3,0].fill_between(fm,b4-sig_b4,b4+sig_b4, color=b_color, alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
axs[3,0].fill_between(fm,c4-sig_c4,c4+sig_c4, color=c_color, alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
axs[3,0].plot(fm,c4_tilde, color=c_tilde_color, label=r'Model $\tilde{\mathrm{c}}$')

axs[3,0].set_ylabel('$V_{^3P_1}$ [MeV]', fontsize=label_font_size)

# phase shift
a40=model_a_phase[7]
sig_a40=model_a_phase[8]
b40=model_b_phase[7]
sig_b40=model_b_phase[8]
c40=model_c_phase[7]
sig_c40=model_c_phase[8]
c40_tilde=model_c_tilde_phase[7]

axs[3,1].fill_between(lab_energy,a40-sig_a40,a40+sig_a40, color=a_color, alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
axs[3,1].fill_between(lab_energy,b40-sig_b40,b40+sig_b40, color=b_color, alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
axs[3,1].fill_between(lab_energy,c40-sig_c40,c40+sig_c40, color=c_color, alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
axs[3,1].plot(lab_energy,c40_tilde, color=c_tilde_color, label=r'Model $\tilde{\mathrm{c}}$')

phases_3P1 = [-0.10713374,-0.92126694,-2.03069139,-4.80541426,-8.17251143,-13.23109890,-17.53653207,
            -21.46183168,-25.08610466,-28.43998069,-31.54449062]
axs[3,1].scatter(MeV,phases_3P1, color=phases_color, label=r'Phases from Database')

axs[3,1].set_ylabel('$\delta_{^3P_1}$ [deg]', fontsize=label_font_size)

# 3S1 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# partial wave
a5=model_a[9]
sig_a5=model_a[10]
b5=model_b[9]
sig_b5=model_b[10]
c5=model_c[9]
sig_c5=model_c[10]
c5_tilde=model_c_tilde[9]

axs[4,0].fill_between(fm,a5-sig_a5,a5+sig_a5, color=a_color, alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
axs[4,0].fill_between(fm,b5-sig_b5,b5+sig_b5, color=b_color, alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
axs[4,0].fill_between(fm,c5-sig_c5,c5+sig_c5, color=c_color, alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
axs[4,0].plot(fm,c5_tilde, color=c_tilde_color, label=r'Model $\tilde{\mathrm{c}}$')

axs[4,0].set_ylabel('$V_{^3S_1}$ [MeV]', fontsize=label_font_size)

# phase shift
a50=model_a_phase[9]
sig_a50=model_a_phase[10]
b50=model_b_phase[9]
sig_b50=model_b_phase[10]
c50=model_c_phase[9]
sig_c50=model_c_phase[10]
c50_tilde=model_c_tilde_phase[9]

axs[4,1].fill_between(lab_energy,a50-sig_a50,a50+sig_a50, color=a_color, alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
axs[4,1].fill_between(lab_energy,b50-sig_b50,b50+sig_b50, color=b_color, alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
axs[4,1].fill_between(lab_energy,c50-sig_c50,c50+sig_c50, color=c_color, alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
axs[4,1].plot(lab_energy,c50_tilde, color=c_tilde_color, label=r'Model $\tilde{\mathrm{c}}$')

phases_3S1 = [147.73037784,118.15091440,102.57631231,80.57883595,62.68973039,
            43.11002395,30.59218536,21.14806060,13.44753520,6.89699385,1.13750821]
axs[4,1].scatter(MeV,phases_3S1, color=phases_color, label=r'Phases from Database')

axs[4,1].set_ylabel('$\delta_{^3S_1}$ [deg]', fontsize=label_font_size)

# e1 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# partial wave
a6=model_a[11]
sig_a6=model_a[12]
b6=model_b[11]
sig_b6=model_b[12]
c6=model_c[11]
sig_c6=model_c[12]
c6_tilde=model_c_tilde[11]

axs[5,0].fill_between(fm,a6-sig_a6,a6+sig_a6, color=a_color, alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
axs[5,0].fill_between(fm,b6-sig_b6,b6+sig_b6, color=b_color, alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
axs[5,0].fill_between(fm,c6-sig_c6,c6+sig_c6, color=c_color, alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
axs[5,0].plot(fm,c6_tilde, color=c_tilde_color, label=r'Model $\tilde{\mathrm{c}}$')

axs[5,0].set_ylabel('$V_{\epsilon_1}$ [MeV]', fontsize=label_font_size)

# phase shift
a60=model_a_phase[11]
sig_a60=model_a_phase[12]
b60=model_b_phase[11]
sig_b60=model_b_phase[12]
c60=model_c_phase[11]
sig_c60=model_c_phase[12]
c60_tilde=model_c_tilde_phase[11]

axs[5,1].fill_between(lab_energy,a60-sig_a60,a60+sig_a60, color=a_color, alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
axs[5,1].fill_between(lab_energy,b60-sig_b60,b60+sig_b60, color=b_color, alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
axs[5,1].fill_between(lab_energy,c60-sig_c60,c60+sig_c60, color=c_color, alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
axs[5,1].plot(lab_energy,c60_tilde, color=c_tilde_color, label=r'Model $\tilde{\mathrm{c}}$')

phases_epsilon1 = [0.10620739,0.66890506,1.15128011,1.76897828,2.07623784,2.41622613,
                2.82044047,3.30051646,3.82306010,4.36378521,4.91243134]
axs[5,1].scatter(MeV,phases_epsilon1, color=phases_color, label=r'Phases from Database')

axs[5,1].set_ylabel('$\delta_{\epsilon_1}$ [deg]', fontsize=label_font_size)

# 3D1 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# partial wave
a7=model_a[13]
sig_a7=model_a[14]
b7=model_b[13]
sig_b7=model_b[14]
c7=model_c[13]
sig_c7=model_c[14]
c7_tilde=model_c_tilde[13]

axs[6,0].fill_between(fm,a7-sig_a7,a7+sig_a7, color=a_color, alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
axs[6,0].fill_between(fm,b7-sig_b7,b7+sig_b7, color=b_color, alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
axs[6,0].fill_between(fm,c7-sig_c7,c7+sig_c7, color=c_color, alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
axs[6,0].plot(fm,c7_tilde, color=c_tilde_color, label=r'Model $\tilde{\mathrm{c}}$')

axs[6,0].set_ylabel('$V_{^3D_1}$ [MeV]', fontsize=label_font_size)

# phase shift
a70=model_a_phase[13]
sig_a70=model_a_phase[14]
b70=model_b_phase[13]
sig_b70=model_b_phase[14]
c70=model_c_phase[13]
sig_c70=model_c_phase[14]
c70_tilde=model_c_tilde_phase[13]

axs[6,1].fill_between(lab_energy,a70-sig_a70,a70+sig_a70, color=a_color, alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
axs[6,1].fill_between(lab_energy,b70-sig_b70,b70+sig_b70, color=b_color, alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
axs[6,1].fill_between(lab_energy,c70-sig_c70,c70+sig_c70, color=c_color, alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
axs[6,1].plot(lab_energy,c70_tilde, color=c_tilde_color, label=r'Model $\tilde{\mathrm{c}}$')

phases_3D1 = [-0.00169272,-0.17657032,-0.66856504,-2.78836511,-6.41936998,-12.24836913,
            -16.54107498,-19.81555724,-22.38062099,-24.42690859,-26.07216905]
axs[6,1].scatter(MeV,phases_3D1, color=phases_color, label=r'Phases from Database')

axs[6,1].set_ylabel('$\delta_{^3D_1}$ [deg]', fontsize=label_font_size)

# 1D2 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# partial wave
a8=model_a[15]
sig_a8=model_a[16]
b8=model_b[15]
sig_b8=model_b[16]
c8=model_c[15]
sig_c8=model_c[16]
c8_tilde=model_c_tilde[15]

axs[7,0].fill_between(fm,a8-sig_a8,a8+sig_a8, color=a_color, alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
axs[7,0].fill_between(fm,b8-sig_b8,b8+sig_b8, color=b_color, alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
axs[7,0].fill_between(fm,c8-sig_c8,c8+sig_c8, color=c_color, alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
axs[7,0].plot(fm,c8_tilde, color=c_tilde_color, label=r'Model $\tilde{\mathrm{c}}$')

axs[7,0].set_ylabel('$V_{^1D_2}$ [MeV]', fontsize=label_font_size)
axs[7,0].set_xlabel('r [fm]', fontsize=label_font_size)

# phase shift
a80=model_a_phase[15]
sig_a80=model_a_phase[16]
b80=model_b_phase[15]
sig_b80=model_b_phase[16]
c80=model_c_phase[15]
sig_c80=model_c_phase[16]
c80_tilde=model_c_tilde_phase[15]

axs[7,1].fill_between(lab_energy,a80-sig_a80,a80+sig_a80, color=a_color, alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
axs[7,1].fill_between(lab_energy,b80-sig_b80,b80+sig_b80, color=b_color, alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
axs[7,1].fill_between(lab_energy,c80-sig_c80,c80+sig_c80, color=c_color, alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
axs[7,1].plot(lab_energy,c80_tilde, color=c_tilde_color, label=r'Model $\tilde{\mathrm{c}}$')

phases_1D2 = [0.00077429, 0.04268684, 0.16648250, 0.69830700, 1.70749309, 3.76619775,
              5.63198617, 7.18815928, 8.44841295, 9.47113256, 10.32159769]
axs[7,1].scatter(MeV,phases_1D2, color=phases_color, label=r'Phases from Database')

axs[7,1].set_ylabel('$\delta_{^1D_2}$ [deg]', fontsize=label_font_size)
axs[7,1].set_xlabel('Lab Energy [MeV]', fontsize=label_font_size)

# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Out:
# Text(0.5, 0, 'Lab Energy [MeV]')
