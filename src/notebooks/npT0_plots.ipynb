# %%
# for np T=0, corresponding to fig. 2 on pg. 9 in "Minimally nonlocal..."
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

model_a = np.loadtxt('../model_a_np_phases.dat', unpack=True, skiprows=1)
model_b = np.loadtxt('../model_b_np_phases.dat', unpack=True, skiprows=1)
model_c = np.loadtxt('../model_c_np_phases.dat', unpack=True, skiprows=1)

model_a_tilde = np.loadtxt('../model_a_tilde_np_phases.dat', unpack=True, skiprows=1)
model_b_tilde = np.loadtxt('../model_b_tilde_np_phases.dat', unpack=True, skiprows=1)
model_c_tilde = np.loadtxt('../model_c_tilde_np_phases.dat', unpack=True, skiprows=1)

lab_energy=model_a[0]
lab_energy_tilde=model_a_tilde[0]
MeV = [1.00000000,5.00000000,10.00000000,25.00000000,50.00000000,100.00000000,
        150.00000000,200.00000000,250.00000000,300.00000000,350.00000000]

# %%
# 1P1 : models fitted to 125 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a=model_a[5]
sig_a=model_a[6]
b=model_b[5]
sig_b=model_b[6]
c=model_c[5]
sig_c=model_c[6]

# plots of models
ax.fill_between(lab_energy,a-sig_a,a+sig_a, color='#ee9b00', alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
ax.fill_between(lab_energy,b-sig_b,b+sig_b, color='#ae2012', alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
ax.fill_between(lab_energy,c-sig_c,c+sig_c, color='#005f73', alpha=0.75, label=r'Model c $\pm \sigma_{c}$')

# array of phases from phases_database.dat
phases_1P1 = [-0.19054091,-1.50739157,-3.08935863,-6.44480830,-9.88227497,
            -14.59991415,-18.44340152,-21.74890107,-24.58334706,-26.99613941,-29.04322442]
plt.scatter(MeV,phases_1P1, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,-30.0), 300.0, 30.0, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='upper right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 2.1: $^{1}P_{1}$ fitted to 125 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(-30,0)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(-30,0,10))

plt.show()


# 1P1 : models fitted to 200 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a_tilde=model_a_tilde[5]
sig_a_tilde=model_a_tilde[6]
b_tilde=model_b_tilde[5]
sig_b_tilde=model_b_tilde[6]
c_tilde=model_c_tilde[5]
sig_c_tilde=model_c_tilde[6]

# plots of models
ax.fill_between(lab_energy_tilde,a_tilde-sig_a_tilde,a_tilde+sig_a_tilde, color='#ee9b00', alpha=0.75, label=r'Model $\tilde{a} \pm \sigma_{\tilde{a}}$')
ax.fill_between(lab_energy,b_tilde-sig_b_tilde,b_tilde+sig_b_tilde, color='#ae2012', alpha=0.75, label=r'Model $\tilde{b} \pm \sigma_{\tilde{c}}$')
ax.fill_between(lab_energy,c_tilde-sig_c_tilde,c_tilde+sig_c_tilde, color='#005f73', alpha=0.75, label=r'Model $\tilde{c} \pm \sigma_{\tilde{b}}$')

# array of phases from phases_database.dat
phases_1P1 = [-0.19054091,-1.50739157,-3.08935863,-6.44480830,-9.88227497,
            -14.59991415,-18.44340152,-21.74890107,-24.58334706,-26.99613941,-29.04322442]
plt.scatter(MeV,phases_1P1, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,-30.0), 300.0, 30.0, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='upper right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 2.2: $^{1}P_{1}$ fitted to 200 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(-30,0)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(-30,0,10))

plt.show()

# %%
# 3S1 : models fitted to 125 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a=model_a[9]
sig_a=model_a[10]
b=model_b[9]
sig_b=model_b[10]
c=model_c[9]
sig_c=model_c[10]

# plots of models
ax.fill_between(lab_energy,a-sig_a,a+sig_a, color='#ee9b00', alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
ax.fill_between(lab_energy,b-sig_b,b+sig_b, color='#ae2012', alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
ax.fill_between(lab_energy,c-sig_c,c+sig_c, color='#005f73', alpha=0.75, label=r'Model c $\pm \sigma_{c}$')

# array of phases from phases_database.dat
phases_3S1 = [147.73037784,118.15091440,102.57631231,80.57883595,62.68973039,
            43.11002395,30.59218536,21.14806060,13.44753520,6.89699385,1.13750821]
plt.scatter(MeV,phases_3S1, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,0.0), 300.0, 150.0, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='upper right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 2.3: $^{3}S_{1}$ fitted to 125 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(0,150)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(0,150,50))

plt.show()


# 3S1 : models fitted to 200 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a_tilde=model_a_tilde[9]
sig_a_tilde=model_a_tilde[10]
b_tilde=model_b_tilde[9]
sig_b_tilde=model_b_tilde[10]
c_tilde=model_c_tilde[9]
sig_c_tilde=model_c_tilde[10]

# plots of models
ax.fill_between(lab_energy_tilde,a_tilde-sig_a_tilde,a_tilde+sig_a_tilde, color='#ee9b00', alpha=0.75, label=r'Model $\tilde{a} \pm \sigma_{\tilde{a}}$')
ax.fill_between(lab_energy,b_tilde-sig_b_tilde,b_tilde+sig_b_tilde, color='#ae2012', alpha=0.75, label=r'Model $\tilde{b} \pm \sigma_{\tilde{c}}$')
ax.fill_between(lab_energy,c_tilde-sig_c_tilde,c_tilde+sig_c_tilde, color='#005f73', alpha=0.75, label=r'Model $\tilde{c} \pm \sigma_{\tilde{b}}$')

# array of phases from phases_database.dat
phases_3S1 = [147.73037784,118.15091440,102.57631231,80.57883595,62.68973039,
            43.11002395,30.59218536,21.14806060,13.44753520,6.89699385,1.13750821]
plt.scatter(MeV,phases_3S1, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,0.0), 300.0, 150.0, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='upper right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 2.4: $^{3}S_{1}$ fitted to 200 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(0,150)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(0,150,50))

plt.show()

# %%
# 3D2 : models fitted to 125 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a=model_a[17]
sig_a=model_a[18]
b=model_b[17]
sig_b=model_b[18]
c=model_c[17]
sig_c=model_c[18]

# plots of models
ax.fill_between(lab_energy,a-sig_a,a+sig_a, color='#ee9b00', alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
ax.fill_between(lab_energy,b-sig_b,b+sig_b, color='#ae2012', alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
ax.fill_between(lab_energy,c-sig_c,c+sig_c, color='#005f73', alpha=0.75, label=r'Model c $\pm \sigma_{c}$')

# array of phases from phases_database.dat
phases_3D2 = [0.00708024,0.22285267,0.85231039,3.73703905,9.01427813,17.26863598,22.06005506,24.40573997,
            25.22947744,25.12120730,24.44403838]
plt.scatter(MeV,phases_3D2, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,0.0), 300.0, 30.0, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='lower right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 2.5: $^{3}D_{2} fitted to 125 MeV$', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(0,30)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(0,30,5))

plt.show()


# 3D2 : models fitted to 200 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a_tilde=model_a_tilde[17]
sig_a_tilde=model_a_tilde[18]
b_tilde=model_b_tilde[17]
sig_b_tilde=model_b_tilde[18]
c_tilde=model_c_tilde[17]
sig_c_tilde=model_c_tilde[18]

# plots of models
ax.fill_between(lab_energy_tilde,a_tilde-sig_a_tilde,a_tilde+sig_a_tilde, color='#ee9b00', alpha=0.75, label=r'Model $\tilde{a} \pm \sigma_{\tilde{a}}$')
ax.fill_between(lab_energy,b_tilde-sig_b_tilde,b_tilde+sig_b_tilde, color='#ae2012', alpha=0.75, label=r'Model $\tilde{b} \pm \sigma_{\tilde{c}}$')
ax.fill_between(lab_energy,c_tilde-sig_c_tilde,c_tilde+sig_c_tilde, color='#005f73', alpha=0.75, label=r'Model $\tilde{c} \pm \sigma_{\tilde{b}}$')

# array of phases from phases_database.dat
phases_3D2 = [0.00708024,0.22285267,0.85231039,3.73703905,9.01427813,17.26863598,22.06005506,24.40573997,
            25.22947744,25.12120730,24.44403838]
plt.scatter(MeV,phases_3D2, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,0.0), 300.0, 30.0, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='lower right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 2.6: $^{3}D_{2}$ fitted to 200 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(0,30)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(0,30,5))

plt.show()

# %%
# 3D1 : models fitted to 125 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a=model_a[13]
sig_a=model_a[14]
b=model_b[13]
sig_b=model_b[14]
c=model_c[13]
sig_c=model_c[14]

# plots of models
ax.fill_between(lab_energy,a-sig_a,a+sig_a, color='#ee9b00', alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
ax.fill_between(lab_energy,b-sig_b,b+sig_b, color='#ae2012', alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
ax.fill_between(lab_energy,c-sig_c,c+sig_c, color='#005f73', alpha=0.75, label=r'Model c $\pm \sigma_{c}$')

# array of phases from phases_database.dat
phases_3D1 = [-0.00169272,-0.17657032,-0.66856504,-2.78836511,-6.41936998,-12.24836913,
            -16.54107498,-19.81555724,-22.38062099,-24.42690859,-26.07216905]
plt.scatter(MeV,phases_3D1, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,-30.0), 300.0, 30.0, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='upper right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
# plt.title('Fig. 2.9: $^{3}D_{1}$ fitted to 125 MeV', fontsize=20)

# Set limits
plt.xlim(0,125)
plt.ylim(-30,0)

plt.xticks(np.arange(0,125,50))
plt.yticks(np.arange(-30,0,5))

plt.show()


# 3D1 : models fitted to 200 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a_tilde=model_a_tilde[13]
sig_a_tilde=model_a_tilde[14]
b_tilde=model_b_tilde[13]
sig_b_tilde=model_b_tilde[14]
c_tilde=model_c_tilde[13]
sig_c_tilde=model_c_tilde[14]

# plots of models
ax.fill_between(lab_energy_tilde,a_tilde-sig_a_tilde,a_tilde+sig_a_tilde, color='#ee9b00', alpha=0.75, label=r'Model $\tilde{a} \pm \sigma_{\tilde{a}}$')
ax.fill_between(lab_energy,b_tilde-sig_b_tilde,b_tilde+sig_b_tilde, color='#ae2012', alpha=0.75, label=r'Model $\tilde{b} \pm \sigma_{\tilde{c}}$')
ax.fill_between(lab_energy,c_tilde-sig_c_tilde,c_tilde+sig_c_tilde, color='#005f73', alpha=0.75, label=r'Model $\tilde{c} \pm \sigma_{\tilde{b}}$')

# array of phases from phases_database.dat
phases_3D1 = [-0.00169272,-0.17657032,-0.66856504,-2.78836511,-6.41936998,-12.24836913,
            -16.54107498,-19.81555724,-22.38062099,-24.42690859,-26.07216905]
plt.scatter(MeV,phases_3D1, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,-30.0), 300.0, 30.0, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='upper right', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('$^{3}D_{1}$ fitted to 200 MeV', fontsize=20)

# Set limits
plt.xlim(0,200)
plt.ylim(-30,0)

plt.xticks(np.arange(0,200,50))
plt.yticks(np.arange(-30,0,5))

plt.show()

# %%
# 3D3 : models fitted to 125 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a=model_a[29]
sig_a=model_a[30]
b=model_b[29]
sig_b=model_b[30]
c=model_c[29]
sig_c=model_c[30]

# plots of models
ax.fill_between(lab_energy,a-sig_a,a+sig_a, color='#ee9b00', alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
ax.fill_between(lab_energy,b-sig_b,b+sig_b, color='#ae2012', alpha=0.75, label=r'Model b $\pm \sigma_{b}$')
ax.fill_between(lab_energy,c-sig_c,c+sig_c, color='#005f73', alpha=0.75, label=r'Model c $\pm \sigma_{c}$')

# array of phases from phases_database.dat
phases_3D3 = [-0.00012012,-0.00009914,0.00549237,0.05770070,0.35986396,1.50034988,
            2.75238123,3.75305529,4.41081584,4.74792631,4.82274186]
plt.scatter(MeV,phases_3D3, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,0.0), 300.0, 4.5, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='upper left', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 2.11: $^{3}D_{3}$ fitted to 125 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(0,13)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(0,13,2))

plt.show()


# 3D3 : models fitted to 200 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a_tilde=model_a_tilde[29]
sig_a_tilde=model_a_tilde[30]
b_tilde=model_b_tilde[29]
sig_b_tilde=model_b_tilde[30]
c_tilde=model_c_tilde[29]
sig_c_tilde=model_c_tilde[30]

# plots of models
ax.fill_between(lab_energy_tilde,a_tilde-sig_a_tilde,a_tilde+sig_a_tilde, color='#ee9b00', alpha=0.75, label=r'Model $\tilde{a} \pm \sigma_{\tilde{a}}$')
ax.fill_between(lab_energy,b_tilde-sig_b_tilde,b_tilde+sig_b_tilde, color='#ae2012', alpha=0.75, label=r'Model $\tilde{b} \pm \sigma_{\tilde{c}}$')
ax.fill_between(lab_energy,c_tilde-sig_c_tilde,c_tilde+sig_c_tilde, color='#005f73', alpha=0.75, label=r'Model $\tilde{c} \pm \sigma_{\tilde{b}}$')

# array of phases from phases_database.dat
phases_3D3 = [-0.00012012,-0.00009914,0.00549237,0.05770070,0.35986396,1.50034988,
            2.75238123,3.75305529,4.41081584,4.74792631,4.82274186]
plt.scatter(MeV,phases_3D3, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,0.0), 300.0, 4.5, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='upper left', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 2.12: $^{3}D_{3}$ fitted to 200 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(0,13)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(0,13,2))

plt.show()

# %%
# e1 : models fitted to 125 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a=model_a[11]
sig_a=model_a[12]
b=model_b[11]
sig_b=model_b[12]
c=model_c[11]
sig_c=model_c[12]

# plots of models
ax.fill_between(lab_energy,c-sig_c,c+sig_c, color='#005f73', alpha=0.75, label=r'Model c $\pm \sigma_{c}$')
ax.fill_between(lab_energy,a-sig_a,a+sig_a, color='#ee9b00', alpha=0.75, label=r'Model a $\pm \sigma_{a}$')
ax.fill_between(lab_energy,b-sig_b,b+sig_b, color='#ae2012', alpha=0.75, label=r'Model b $\pm \sigma_{b}$')

# array of phases from phases_database.dat
phases_epsilon1 = [0.10620739,0.66890506,1.15128011,1.76897828,2.07623784,2.41622613,
                2.82044047,3.30051646,3.82306010,4.36378521,4.91243134]
plt.scatter(MeV,phases_epsilon1, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,0.0), 300.0, 4.75, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='lower center', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 2.13: $\epsilon_{1}$ fitted to 125 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(0,5)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(0,5,1))

plt.show()


# e1 : models fitted to 200 MeV ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
fig, ax = plt.subplots(1, figsize=(8,8))

a_tilde=model_a_tilde[11]
sig_a_tilde=model_a_tilde[12]
b_tilde=model_b_tilde[11]
sig_b_tilde=model_b_tilde[12]
c_tilde=model_c_tilde[11]
sig_c_tilde=model_c_tilde[12]

# plots of models
ax.fill_between(lab_energy_tilde,a_tilde-sig_a_tilde,a_tilde+sig_a_tilde, color='#ee9b00', alpha=0.75, label=r'Model $\tilde{a} \pm \sigma_{\tilde{a}}$')
ax.fill_between(lab_energy,b_tilde-sig_b_tilde,b_tilde+sig_b_tilde, color='#ae2012', alpha=0.75, label=r'Model $\tilde{b} \pm \sigma_{\tilde{c}}$')
ax.fill_between(lab_energy,c_tilde-sig_c_tilde,c_tilde+sig_c_tilde, color='#005f73', alpha=0.75, label=r'Model $\tilde{c} \pm \sigma_{\tilde{b}}$')

# array of phases from phases_database.dat
phases_epsilon1 = [0.10620739,0.66890506,1.15128011,1.76897828,2.07623784,2.41622613,
                2.82044047,3.30051646,3.82306010,4.36378521,4.91243134]
plt.scatter(MeV,phases_epsilon1, color='#14213d', label=r'Phases from Database')

# uncomment to add rectangle with same dimensions as plots in "Minimally nonlocal..."
# ax.add_patch(Rectangle((0.0,0.0), 300.0, 4.75, angle=0.0, edgecolor='black', facecolor='none', ls='-', zorder=0))

plt.legend(loc='lower center', fontsize=15)
plt.xlabel('Lab Energy [MeV]', fontsize=15)
plt.ylabel('Phase Shift [deg]', fontsize=15)
plt.title('Fig. 2.4: $\epsilon_{1}$ fitted to 200 MeV', fontsize=20)

# Set limits
plt.xlim(0,350)
plt.ylim(0,5)

plt.xticks(np.arange(0,350,50))
plt.yticks(np.arange(0,5,1))

plt.show()
